# %% [markdown]
# # Time : 1 hour
#
# # Problem Statement

# %% [markdown]
# ### A student is taking a cryptography class and has found anagrams to be very useful. Two strings are anagrams of each other if the first string's letters can be rearranged to form the second string. In other words, both strings must contain the same exact letters in the same exact frequency. For example, bacdc and dcbac are anagrams, but bacdc and dcbad are not.
#
# ### The student decides on an encryption scheme that involves two large strings. The encryption is dependent on the minimum number of character deletions required to make the two strings anagrams. You need to determine this number.
#
# ### Given two strings, $a$ and $b$, that may or may not be of the same length, determine the minimum number of character deletions required to make $a$ and $b$ anagrams. Any characters can be deleted from either of the strings. The strings $a$ and $b$ consist of lowercase English alphabets.

# %% [markdown]
# **Example**
#
# <code>a = 'cde'</code>
#
# <code>b = 'dcf' </code>

# %% [markdown]
# ### Delete $e$ from $a$ and $f$ from $b$ so that the remaining strings are $cd$ and $dc$ which are anagrams. This takes 2 character deletions.

# %% [markdown]
# ## **Function Description**
#
# ### Create a <code>makeAnagram</code> function below.
#
# ### **Inputs:**
#
# ### string a: a string
#
# ### string b: another string
#
# ### **Output:**
#
# ### int: the minimum total characters that must be deleted

# %% [markdown]
# # Solution

# %%
def makeAnagram(first_string, second_string):
  '''
  Takes two input and returns anagram and number of chareters to be remove to make anagram
  '''
  first_sentence = list(first_string)
  print(first_sentence)
  second_sentence = list(second_string)
  print(second_sentence)
  first_anagram = []
  second_angram = []
  
  if second_sentence!=[] and first_sentence!=[]:
    for index, word in enumerate(first_string):
      print(word)
      

      for index2, word2 in enumerate(second_string):
        print(word,word2)

        if word in second_sentence :
          print(first_sentence,second_sentence)

        
          print(word, word2,index,index2)
          first_anagram.append(word)
          print(first_anagram)
          second_angram.append(word)
          print(second_angram)
          first_sentence.pop(first_sentence.index(word))
          print(first_sentence)
          second_sentence.pop(second_sentence.index(word))
          print(second_sentence)
          break
        


  first_str_order = ''.join(first_anagram)
  second_str_order = ''.join(second_angram)
  print(len(first_sentence)+len(second_sentence))
  print(f"Delete  {''.join(first_sentence)}  from  a  and  {''.join(second_sentence)}  from  b  so that the remaining strings are  {first_str_order}  and  {second_str_order}  which are anagrams. This takes {len(first_sentence)+len(second_sentence)} character deletions.")

# %%
a='asdfv'
b='asd'
makeAnagram(a,b)
# Out:
# ['a', 's', 'd', 'f', 'v']
# ['a', 's', 'd']
# a
# a a
# ['a', 's', 'd', 'f', 'v'] ['a', 's', 'd']
# a a 0 0
# ['a']
# ['a']
# ['s', 'd', 'f', 'v']
# ['s', 'd']
# s
# s a
# ['s', 'd', 'f', 'v'] ['s', 'd']
# s a 1 0
# ['a', 's']
# ['a', 's']
# ['d', 'f', 'v']
# ['d']
# d
# d a
# ['d', 'f', 'v'] ['d']
# d a 2 0
# ['a', 's', 'd']
# ['a', 's', 'd']
# ['f', 'v']
# []
# f
# f a
# f s
# f d
# v
# v a
# v s
# v d
# 2
# Delete  fv  from  a  and    from  b  so that the remaining strings are  asd  and  asd  which are anagrams. This takes 2 character deletions.
